# %%
from shape import Shape
print("Sucess")
# Out:
# Sucess

# %%
from circle import Circle

# 1. Create a circle
c1 = Circle(x=0, y=0, radius=5)
print(c1)

# 2. Check area and perimeter 
print(f"Area: {c1.area}")
print(f"Perimeter: {c1.perimeter}")

# 3. Check if it's a unit circle
print(f"Is unit circle: {c1.is_unit_circle()}")

# 4. Test translater method (inherit from Shape)
c1.translate(2,4)
print(f"The new coordinates for c1 are ({c1.x}, {c1.y})")

# 5. Comparison
c2 = Circle(radius=3)
print(f"c1 > c2: {c1 > c2}")
print(f"c1 == c2: {c1 == c2}")
# Out:
# This circle has it's center at (0.0, 0.0) and has the radius 5.0
# Area: 78.53981633974483
# Perimeter: 31.41592653589793
# Is unit circle: False
# The new coordinates for c1 are (2.0, 4.0)
# c1 > c2: True
# c1 == c2: False

# %%
from rectangle import Rectangle

# 1. Create a triangle
r1 = Rectangle(x=0, y=0, width=3, height=4)
print(r1)

# 2. Check area and perimeter
print(f"Area: {r1.area}")
print(f"Perimeter: {r1.perimeter}")

# 3. Check if it's a square
print(f"Is square: {r1.is_square()}")

# 4. Test translater method (inherit from Shape)
r1.translate(2,4)
print(f"The new coordinates for r1 are ({r1.x}, {r1.y})")

# 5. Comparison
r2 = Rectangle(width=5, height=8)
print(f"r1 < r2: {r1 < r2}")
print(f"c1 == c2: {r1 == r2}")
# Out:
# This rectangle has it's center at (0.0, 0.0), width 3.0 and height 4.0
# Area: 12.0
# Perimeter: 14.0
# Is square: False
# The new coordinates for r1 are (2.0, 4.0)
# r1 < r2: True
# c1 == c2: False

# %%
from sphere import Sphere

s = Sphere(x=0, y=0, z=0, radius=5)
print(s)

print(f"Surface area: {s.surface_area}")
print(f"Volume: {s.volume}")
print(f"Is spehere unit sphere: {s.is_unit_sphere()}")
# Out:
# This shere has it's center at (0.0, 0.0, 0.0) and has the radius 5.0
# Surface area: 314.1592653589793
# Volume: 523.5987755982989
# Is spehere unit sphere: False

# %%
from cube import Cube

c = Cube(x=0, y= 0, z=0, side_length=5)
print(c)

c1 = Cube(x=0, y= 0, z=0, side_length=4)

print(f"The cubes volume is {c.volume}")
print(f"The cubes is unit cube: {c.is_unit_cube()}")
print(f"The surface area for c1 is {c1.surface_area}")
# Out:
# This cube has it's center at (0.0, 0.0, 0.0) and has the side length 5.0
# The cubes volume is 125.0
# The cubes is unit cube: False
# The surface area for c1 is 96.0

# %%
from shape2D_plotter import Shape2DPlotter
from circle import Circle

plotter = Shape2DPlotter()
plotter.add_shape(Circle(x=0, y=0, radius=0.5))
plotter.plot()
plotter.show()

# %%
from shape2D_plotter import Shape2DPlotter
from circle import Circle
from rectangle import Rectangle

plotter = Shape2DPlotter()
plotter.add_shape(Circle(x=3, y=4, radius=0.5))
plotter.add_shape(Circle(x=0, y=0, radius=1))
plotter.add_shape(Rectangle(x=5, y=8, width=0.5, height=0.8))
plotter.plot()
plotter.show()
